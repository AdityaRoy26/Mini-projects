# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":["harry","rohan","skillf","shubh"],
    "marks":[92,12,33,53],
    "city":["rampur","kolkata","bareilly","antarctica"]
}

# %%
df=pd.DataFrame(dict1)

# %%
df.to_csv("friends.csv")

# %%
df.to_csv("friends_index_false.csv",index=False)

# %%
df.head(3)
# Out:
#      name  marks      city
# 0   harry     92    rampur
# 1   rohan     12   kolkata
# 2  skillf     33  bareilly

# %%
df.tail(2)
# Out:
#      name  marks        city
# 2  skillf     33    bareilly
# 3   shubh     53  antarctica

# %%
df.describe()
# Out:
#            marks
# count   4.000000
# mean   47.500000
# std    34.063666
# min    12.000000
# 25%    27.750000
# 50%    43.000000
# 75%    62.750000
# max    92.000000

# %%
adi=df.read_csv("train.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16928\396224995.py in ?()
# ----> 1 adi=df.read_csv("train.csv")
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read_csv'

# %%
adi=pd.read_csv("train.csv")

# %%
adi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 adi
#
# NameError: name 'adi' is not defined

# %%
adi["speed"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 adi["speed"]
#
# NameError: name 'adi' is not defined

# %%
adi["speed"][0]=50
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 adi["speed"][0]=50
#
# NameError: name 'adi' is not defined

# %%
adi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 adi
#
# NameError: name 'adi' is not defined

# %%
adi["speed"][0] = 50

# %%
adi.loc[0, "speed"] = 50
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 adi.loc[0, "speed"] = 50
#
# NameError: name 'adi' is not defined

# %%
harry=pd.read_csv("train.csv")

# %%
harry
# Out:
#    Train no  speed        city
# 0     12334     92      rampur
# 1     23422     87     kolkata
# 2     12434     56    bareilly
# 3     23423     78  antarctica

# %%
harry["speed"][0] = 50
# Out:
# C:\Users\soumik\AppData\Local\Temp\ipykernel_16928\1962742037.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   harry["speed"][0] = 50

# %%
harry
# Out:
#    Train no  speed        city
# 0     12334     92      rampur
# 1     23422     87     kolkata
# 2     12434     56    bareilly
# 3     23423     78  antarctica

# %%
df.to_csv("train.csv",index=False)

# %%
df
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     12     kolkata
# 2  skillf     33    bareilly
# 3   shubh     53  antarctica

# %%
haryy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 haryy
#
# NameError: name 'haryy' is not defined

# %%
harry
# Out:
#    Train no  speed        city
# 0     12334     92      rampur
# 1     23422     87     kolkata
# 2     12434     56    bareilly
# 3     23423     78  antarctica

# %%
harry.to_csv("train.csv",index =False)

# %%
harry
# Out:
#    Train no  speed        city
# 0     12334     92      rampur
# 1     23422     87     kolkata
# 2     12434     56    bareilly
# 3     23423     78  antarctica

# %%
 harry.index=["first","second","third","fourth"]

# %%
harry
# Out:
#         Train no  speed        city
# first      12334     92      rampur
# second     23422     87     kolkata
# third      12434     56    bareilly
# fourth     23423     78  antarctica

# %%
sr=pd.Series(np.random.rand(34))

# %%
sr
# Out:
# 0     0.428695
# 1     0.435941
# 2     0.556662
# 3     0.000753
# 4     0.427151
# 5     0.770615
# 6     0.988489
# 7     0.881265
# 8     0.632548
# 9     0.045892
# 10    0.654374
# 11    0.976917
# 12    0.579223
# 13    0.955945
# 14    0.256529
# 15    0.514456
# 16    0.238095
# 17    0.194291
# 18    0.128476
# 19    0.424915
# 20    0.648288
# 21    0.970400
# 22    0.643248
# 23    0.387562
# 24    0.150948
# 25    0.315193
# 26    0.558033
# 27    0.360556
# 28    0.339171
# 29    0.914573
# 30    0.698483
# 31    0.686473
# 32    0.644611
# 33    0.693260
# dtype: float64

# %%
type(sr)
# Out:
# pandas.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index = np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.130340  0.485808  0.131965  0.587107  0.654741
# 1  0.634796  0.759679  0.736930  0.601172  0.229649
# 2  0.804179  0.933052  0.675194  0.829304  0.494099
# 3  0.346147  0.810308  0.122496  0.759406  0.085348
# 4  0.966907  0.348734  0.432317  0.386624  0.104018

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.493921    0.469711    0.510748    0.480035    0.502008
# std      0.294921    0.282294    0.295628    0.284570    0.272469
# min      0.002178    0.003692    0.000568    0.004425    0.002389
# 25%      0.227752    0.236220    0.258638    0.220128    0.284041
# 50%      0.491205    0.467640    0.519851    0.483514    0.510268
# 75%      0.770859    0.693106    0.776020    0.720514    0.719244
# max      0.998401    0.993590    0.999059    0.982746    0.994790

# %%
newdf[0][0] = "harry"
# Out:
# C:\Users\soumik\AppData\Local\Temp\ipykernel_16928\2771891818.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment.
# Such chained assignment never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# Try using '.loc[row_indexer, col_indexer] = value' instead, to perform the assignment in a single step.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html#chained-assignment
#   newdf[0][0] = "harry"
# ---------------------------------------------------------------------------
# LossySetitemError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:1090, in Series.__setitem__(self, key, value)
#    1089 try:
# ...

# %%
newdf.dtype

# %%
newdf.dtypes

# %%
newdf[0][0] = "harry"

# %%
newdf

# %%
newdf[0] = "harry"

# %%
newdf

# %%
newdf[0][0] ="adii"

# %%
newdf.loc[0, 0] = " adii"

# %%
newdf.head()

# %%
newdf.dtypes

# %%
newdf.columns

# %%
newdf.to_numpy()

# %%
newdf.T

# %%
newdf.sort()

# %%
newdf.sort_index(axis = 0, ascending=False)

# %%
newdf[0]

# %%
type(newdf[0])

# %%
newdf.loc[1,0] = "harrish"

# %%
newdf

# %%
newdf.columns=list("ABCDE")

# %%
newdf.head()

# %%
newdf.rows=list("abcde")

# %%
newdf.drop("E",axis= 1)

# %%
newdf.loc[[1,2], : ]

# %%
newdf.loc[(newdf["B"]>0.6)]

# %%
newdf.loc[(newdf["B"]>0.6) & (newdf["C"]<0.3)]

# %%
 newdf.drop(newdf[0])

# %%
newdf.drop([0])

# %%
newdf.drop(["A","D"], axis=1)

# %%
newdf.drop(["A","D"], axis=1, inplace=True)

# %%
newdf

# %%
newdf.drop([1,5], axis=0)

# %%
newdf.reset_index(drop=True, inplace=True)

# %%
newdf.head(4)

# %%
newdf["B"].isnull()

# %%
newdf.loc[ :,["B"]]= None

# %%
data ={
   'date':],[pd.Timestamp('2023-01-01'), pd.NaT, pd.Timestamp('2023-01-03')],
   'value':[10, 20, 30]

# %%
newdf.dropna(how="all", axis=1)

# %%
df = pd.DataFrame({
    "name": ["A", "B", "C", "D", None],
    "age": [20, None, 25, 30, 22],
    "speed": [10, 20, None, 40, None]
})

# %%
df

# %%
df.drop_duplicates(subset=["name"],keep=False)

# %%
df.shape

# %%
df.info()

# %%
df.info()

# %%
df.info()

# %%
df.shape

# %%
df.drop_duplicates(subset=["name"],keep=False)
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     12     kolkata
# 2  skillf     33    bareilly
# 3   shubh     53  antarctica

# %%
df.head()
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     12     kolkata
# 2  skillf     33    bareilly
# 3   shubh     53  antarctica

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     12  kolkata
